# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Gender
! ls
# Out:
# /content/drive/My Drive/Gender
# Input  Output

# %% [markdown]
# ## Import Libraries/ Functions

# %%
# Imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2
import os

import tensorflow as tf

from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from keras.models import Sequential,load_model,Model
from keras.layers import Conv2D,MaxPooling2D,AvgPool2D,GlobalAveragePooling2D,Dense,Dropout,BatchNormalization,Flatten,Input
from sklearn.model_selection import train_test_split


from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Import Dataset

# %%
path = "./Input/UTKFace"
pixels = []
age = []
gender = [] 

i=0
for img in os.listdir(path):
  i=i+1
  genders = img.split("_")[1]
  img = cv2.imread(str(path)+"/"+str(img))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img=cv2.resize(img,(100,100))
  pixels.append(np.array(img))
  gender.append(np.array(genders))

pixels = np.array(pixels)
gender = np.array(gender,np.uint64)

# %%
len(pixels)
# Out:
# 13302

# %%
len(gender)
# Out:
# 13302

# %% [markdown]
# ## Split into Train/ Test

# %%
x_train,x_test,y_train,y_test = train_test_split(pixels,gender,random_state=100)

# %%
len(x_train)
# Out:
# 9976

# %%
len(x_test)
# Out:
# 3326

# %% [markdown]
# ## Define CNN Architecture

# %%
input = Input(shape = (100,100,1))

conv1 = Conv2D(32,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(input)
conv1 = Dropout(0.1)(conv1)
conv1 = Activation('relu')(conv1)
pool1 = MaxPooling2D(pool_size = (2,2)) (conv1)

conv2 = Conv2D(64,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool1)
conv2 = Dropout(0.1)(conv2)
conv2 = Activation('relu')(conv2)
pool2 = MaxPooling2D(pool_size = (2,2)) (conv2)

conv3 = Conv2D(128,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool2)
conv3 = Dropout(0.1)(conv3)
conv3 = Activation('relu')(conv3)
pool3 = MaxPooling2D(pool_size = (2,2)) (conv3)

conv4 = Conv2D(256,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool3)
conv4 = Dropout(0.1)(conv4)
conv4 = Activation('relu')(conv4)
pool4 = MaxPooling2D(pool_size = (2,2)) (conv4)

flatten = Flatten()(pool4)

dense_1 = Dense(128,activation='relu')(flatten)

drop_1 = Dropout(0.2)(dense_1)

output = Dense(2,activation="sigmoid")(drop_1)

# %%
model = Model(inputs=input,outputs=output)
model.compile(optimizer="adam",loss=["sparse_categorical_crossentropy"],metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 1)]     0
#
#  conv2d (Conv2D)             (None, 100, 100, 32)      320
#
#  dropout (Dropout)           (None, 100, 100, 32)      0
#
#  activation (Activation)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  dropout_1 (Dropout)         (None, 50, 50, 64)        0
#
#  activation_1 (Activation)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  dropout_2 (Dropout)         (None, 25, 25, 128)       0
#
#  activation_2 (Activation)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  dropout_3 (Dropout)         (None, 12, 12, 256)       0
#
#  activation_3 (Activation)   (None, 12, 12, 256)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 1,567,874
# Trainable params: 1,567,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_path='./Output/gender_model.h5'
checkpointer = ModelCheckpoint(model_path, monitor='loss',verbose=1,save_best_only=True,
                               save_weights_only=False, mode='auto',save_freq='epoch')
callback_list=[checkpointer]

# %% [markdown]
# ## Model Training

# %%
save = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=30,callbacks=[callback_list])
# Out:
# Epoch 1/30
# 312/312 [==============================] - ETA: 0s - loss: 1.3309 - accuracy: 0.7311
# Epoch 1: loss improved from inf to 1.33092, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 21s 27ms/step - loss: 1.3309 - accuracy: 0.7311 - val_loss: 0.6222 - val_accuracy: 0.8160
# Epoch 2/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.5646 - accuracy: 0.8322
# Epoch 2: loss improved from 1.33092 to 0.56441, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 23ms/step - loss: 0.5644 - accuracy: 0.8323 - val_loss: 0.5445 - val_accuracy: 0.8497
# Epoch 3/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.5099 - accuracy: 0.8491
# Epoch 3: loss improved from 0.56441 to 0.50923, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 22ms/step - loss: 0.5092 - accuracy: 0.8492 - val_loss: 0.4920 - val_accuracy: 0.8557
# Epoch 4/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.4568 - accuracy: 0.8658
# Epoch 4: loss improved from 0.50923 to 0.45605, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 23ms/step - loss: 0.4561 - accuracy: 0.8662 - val_loss: 0.4459 - val_accuracy: 0.8662
# Epoch 5/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.4306 - accuracy: 0.8734
# Epoch 5: loss improved from 0.45605 to 0.43046, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.4305 - accuracy: 0.8732 - val_loss: 0.4270 - val_accuracy: 0.8740
# Epoch 6/30
# 312/312 [==============================] - ETA: 0s - loss: 0.4087 - accuracy: 0.8794
# Epoch 6: loss improved from 0.43046 to 0.40873, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.4087 - accuracy: 0.8794 - val_loss: 0.4115 - val_accuracy: 0.8809
# Epoch 7/30
# 312/312 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.8881
# Epoch 7: loss improved from 0.40873 to 0.38587, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 24ms/step - loss: 0.3859 - accuracy: 0.8881 - val_loss: 0.4100 - val_accuracy: 0.8797
# Epoch 8/30
# 312/312 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8906
# Epoch 8: loss improved from 0.38587 to 0.37050, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 23ms/step - loss: 0.3705 - accuracy: 0.8906 - val_loss: 0.4042 - val_accuracy: 0.8740
# Epoch 9/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.8991
# Epoch 9: loss improved from 0.37050 to 0.34381, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 23ms/step - loss: 0.3438 - accuracy: 0.8988 - val_loss: 0.3791 - val_accuracy: 0.8845
# Epoch 10/30
# 311/312 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.9050
# Epoch 10: loss improved from 0.34381 to 0.33096, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 23ms/step - loss: 0.3310 - accuracy: 0.9045 - val_loss: 0.3564 - val_accuracy: 0.8863
# Epoch 11/30
# 311/312 [============================>.] - ETA: 0s - loss: 0.3101 - accuracy: 0.9122
# Epoch 11: loss improved from 0.33096 to 0.31005, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.3101 - accuracy: 0.9123 - val_loss: 0.3623 - val_accuracy: 0.8851
# Epoch 12/30
# 311/312 [============================>.] - ETA: 0s - loss: 0.3004 - accuracy: 0.9118
# Epoch 12: loss improved from 0.31005 to 0.30007, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 22ms/step - loss: 0.3001 - accuracy: 0.9119 - val_loss: 0.3699 - val_accuracy: 0.8794
# Epoch 13/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2882 - accuracy: 0.9166
# Epoch 13: loss improved from 0.30007 to 0.28847, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 24ms/step - loss: 0.2885 - accuracy: 0.9164 - val_loss: 0.3763 - val_accuracy: 0.8677
# Epoch 14/30
# 312/312 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.9208
# Epoch 14: loss improved from 0.28847 to 0.28061, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 22ms/step - loss: 0.2806 - accuracy: 0.9208 - val_loss: 0.3662 - val_accuracy: 0.8767
# Epoch 15/30
# 311/312 [============================>.] - ETA: 0s - loss: 0.2684 - accuracy: 0.9238
# Epoch 15: loss improved from 0.28061 to 0.26826, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.2683 - accuracy: 0.9238 - val_loss: 0.3617 - val_accuracy: 0.8776
# Epoch 16/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2634 - accuracy: 0.9225
# Epoch 16: loss improved from 0.26826 to 0.26342, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 24ms/step - loss: 0.2634 - accuracy: 0.9224 - val_loss: 0.4232 - val_accuracy: 0.8635
# Epoch 17/30
# 312/312 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9311
# Epoch 17: loss improved from 0.26342 to 0.25049, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 24ms/step - loss: 0.2505 - accuracy: 0.9311 - val_loss: 0.3609 - val_accuracy: 0.8915
# Epoch 18/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2554 - accuracy: 0.9265
# Epoch 18: loss did not improve from 0.25049
# 312/312 [==============================] - 7s 23ms/step - loss: 0.2559 - accuracy: 0.9264 - val_loss: 0.3493 - val_accuracy: 0.8915
# Epoch 19/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2501 - accuracy: 0.9321
# Epoch 19: loss improved from 0.25049 to 0.25029, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.2503 - accuracy: 0.9319 - val_loss: 0.3700 - val_accuracy: 0.8665
# Epoch 20/30
# 312/312 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9321
# Epoch 20: loss improved from 0.25029 to 0.24605, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.2460 - accuracy: 0.9321 - val_loss: 0.3493 - val_accuracy: 0.8854
# Epoch 21/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2282 - accuracy: 0.9381
# Epoch 21: loss improved from 0.24605 to 0.22877, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 7s 24ms/step - loss: 0.2288 - accuracy: 0.9376 - val_loss: 0.3588 - val_accuracy: 0.8761
# Epoch 22/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2287 - accuracy: 0.9387
# Epoch 22: loss did not improve from 0.22877
# 312/312 [==============================] - 7s 23ms/step - loss: 0.2289 - accuracy: 0.9384 - val_loss: 0.3839 - val_accuracy: 0.8728
# Epoch 23/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2254 - accuracy: 0.9387
# Epoch 23: loss improved from 0.22877 to 0.22516, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 26ms/step - loss: 0.2252 - accuracy: 0.9388 - val_loss: 0.3708 - val_accuracy: 0.8830
# Epoch 24/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2183 - accuracy: 0.9442
# Epoch 24: loss improved from 0.22516 to 0.21830, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.2183 - accuracy: 0.9441 - val_loss: 0.3713 - val_accuracy: 0.8818
# Epoch 25/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2227 - accuracy: 0.9438
# Epoch 25: loss did not improve from 0.21830
# 312/312 [==============================] - 7s 22ms/step - loss: 0.2225 - accuracy: 0.9438 - val_loss: 0.4037 - val_accuracy: 0.8752
# Epoch 26/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2144 - accuracy: 0.9452
# Epoch 26: loss improved from 0.21830 to 0.21389, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 26ms/step - loss: 0.2139 - accuracy: 0.9454 - val_loss: 0.3727 - val_accuracy: 0.8833
# Epoch 27/30
# 312/312 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9436
# Epoch 27: loss did not improve from 0.21389
# 312/312 [==============================] - 7s 23ms/step - loss: 0.2181 - accuracy: 0.9436 - val_loss: 0.3514 - val_accuracy: 0.8882
# Epoch 28/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2008 - accuracy: 0.9521
# Epoch 28: loss improved from 0.21389 to 0.20072, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 25ms/step - loss: 0.2007 - accuracy: 0.9522 - val_loss: 0.3809 - val_accuracy: 0.8725
# Epoch 29/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2037 - accuracy: 0.9523
# Epoch 29: loss did not improve from 0.20072
# 312/312 [==============================] - 7s 23ms/step - loss: 0.2040 - accuracy: 0.9523 - val_loss: 0.4159 - val_accuracy: 0.8785
# Epoch 30/30
# 310/312 [============================>.] - ETA: 0s - loss: 0.2001 - accuracy: 0.9521
# Epoch 30: loss improved from 0.20072 to 0.20024, saving model to ./Output/gender_model.h5
# 312/312 [==============================] - 8s 26ms/step - loss: 0.2002 - accuracy: 0.9520 - val_loss: 0.4215 - val_accuracy: 0.8812

# %%
train_loss = save.history['loss']
test_loss = save.history['val_loss']
train_accuracy = save.history['accuracy']
test_accuracy = save.history['val_accuracy']

# %%
import numpy as np
train_loss_mean = np.mean(train_loss)
test_loss_mean = np.mean(test_loss)
train_accuracy_mean = np.mean(train_accuracy)
test_accuracy_mean = np.mean(test_accuracy)
print(train_loss_mean)
print(test_loss_mean)
print(train_accuracy_mean)
print(test_accuracy_mean)
# Out:
# 0.3335056925813357
# 0.40042969584465027
# 0.9096832354863484
# 0.8748346328735351

# %%
fig, ax = plt.subplots(ncols=2, figsize=(15,7))

ax = ax.ravel()

ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)

ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)

ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)

ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)

ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)

ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)

fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)
# Out:
# Text(0.5, 0.92, 'Lineplots showing loss and accuracy of CNN model by epochs')
